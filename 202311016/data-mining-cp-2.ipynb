# %% [markdown]
# ## Importing Required Libraries

# %% [markdown]
# In this section, we import the necessary Python libraries and modules for data analysis and machine learning. Each library has a specific purpose.
#
# - `pandas` (aliased as `pd`): Pandas is used for data manipulation and analysis, providing data structures for efficient data handling.
#
# - `numpy` (aliased as `np`): NumPy is a library for numerical and mathematical operations, often used in conjunction with Pandas for data manipulation.
#
# - `matplotlib.pyplot` (aliased as `plt`): Matplotlib is a popular data visualization library, and `pyplot` provides a simple interface for creating plots and charts.
#
# - `seaborn` (aliased as `sns`): Seaborn is used to create attractive and informative statistical graphics.
#
# - `LabelEncoder` from `sklearn.preprocessing`: The LabelEncoder is part of Scikit-Learn and is used to encode categorical labels into numerical values.
#
# - `StandardScaler` from `sklearn.preprocessing`: StandardScaler is used for standardizing (scaling) numerical features in machine learning.
#
# - `MinMaxScaler` from `sklearn.preprocessing`: MinMaxScaler is used for scaling numerical features to a specific range.
#
# - `train_test_split` from `sklearn.model_selection`: This function is used to split data into training and testing sets for model training and evaluation.
#
# - `GridSearchCV` from `sklearn.model_selection`: GridSearchCV is used for hyperparameter tuning using grid search.
#
# - `LogisticRegression` from `sklearn.linear_model`: LogisticRegression is a classification algorithm used for logistic regression.
#
# - `accuracy_score` from `sklearn.metrics`: This function measures the accuracy of classification models.
#
# - `RandomizedSearchCV` from `sklearn.model_selection`: RandomizedSearchCV is used for hyperparameter tuning using randomized search.
#
# - `KNeighborsClassifier` from `sklearn.neighbors`: KNeighborsClassifier is used for k-nearest neighbors classification.
#
# - `SVC` from `sklearn.svm`: SVC (Support Vector Classification) is used for support vector classification.
#
# - `DecisionTreeClassifier` from `sklearn.tree`: DecisionTreeClassifier is used for decision tree-based classification.
#
# - `RandomForestClassifier` from `sklearn.ensemble`: RandomForestClassifier is used for random forest-based classification.
#
# - `precision_score`, `recall_score`, and `confusion_matrix` from `sklearn.metrics`: These are additional evaluation metrics for classification models.
#
# - `warnings`: The `warnings` module is imported to handle warnings in the code.
#
# - `warnings.filterwarnings('ignore')`: This line sets the warning filter to 'ignore,' suppressing non-essential warnings during code execution.
#
# This setup prepares the environment for working with data and machine learning, importing libraries and modules commonly used for data analysis and model building. The 'warnings' filter is set to 'ignore' to maintain a cleaner output when running the code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading Hospital Inpatient Discharge Data
#
# In this section, we are reading hospital inpatient discharge data from a CSV file.

# %% [markdown]
# ### Set Pandas Display Option
#
# Before reading the data, we set a Pandas display option to ensure that all columns in the dataset are visible without truncation. This is helpful for analyzing datasets with a large number of columns.

# %%
pd.set_option('display.max_columns', None)

# %%
hospital_data = pd.read_csv('hospital-inpatient-discharges-sparcs-de-identified-2010-1.csv', low_memory=False)

# %%
hospital_data
# Out:
#            index Health Service Area Hospital County  \
# 0              0      Capital/Adiron          Albany
# 1              1      Capital/Adiron          Albany
# 2              2      Capital/Adiron          Albany
# 3              3      Capital/Adiron          Albany
# 4              4      Capital/Adiron          Albany
# ...          ...                 ...             ...
# 2622128  2622128                 NaN             NaN
# 2622129  2622129                 NaN             NaN
# 2622130  2622130                 NaN             NaN
# 2622131  2622131                 NaN             NaN
# 2622132  2622132                 NaN             NaN
#
#          Operating Certificate Number  Facility ID  \
# 0                            101000.0          1.0
# 1                            101000.0          1.0
# 2                            101000.0          1.0
# 3                            101000.0          1.0
# 4                            101000.0          1.0
# ...                               ...          ...
# 2622128                           NaN          NaN
# 2622129                           NaN          NaN
# 2622130                           NaN          NaN
# 2622131                           NaN          NaN
# 2622132                           NaN          NaN
#
#                                     Facility Name    Age Group  \
# 0                  Albany Medical Center Hospital     18 to 29
# 1                  Albany Medical Center Hospital     50 to 69
# 2                  Albany Medical Center Hospital  70 or Older
# 3                  Albany Medical Center Hospital  70 or Older
# 4                  Albany Medical Center Hospital  70 or Older
# ...                                           ...          ...
# 2622128  Abortion Record - Facility Name Redacted     30 to 49
# 2622129  Abortion Record - Facility Name Redacted     30 to 49
# 2622130  Abortion Record - Facility Name Redacted     30 to 49
# 2622131  Abortion Record - Facility Name Redacted     30 to 49
# 2622132  Abortion Record - Facility Name Redacted     30 to 49
#
#         Zip Code - 3 digits Gender        Race          Ethnicity  \
# 0                       NaN      F       White  Not Span/Hispanic
# 1                       NaN      M       White  Not Span/Hispanic
# 2                       NaN      M       White  Not Span/Hispanic
# 3                       NaN      F       White  Not Span/Hispanic
# 4                       NaN      F       White  Not Span/Hispanic
# ...                     ...    ...         ...                ...
# 2622128                 OOS      F  Other Race  Not Span/Hispanic
# 2622129                 OOS      F  Other Race  Not Span/Hispanic
# 2622130                 OOS      F  Other Race  Not Span/Hispanic
# 2622131                 OOS      F  Other Race  Not Span/Hispanic
# 2622132                 OOS      F  Other Race  Not Span/Hispanic
#
#         Length of Stay Type of Admission                Patient Disposition  \
# 0                    1         Emergency                  Home or Self Care
# 1                   15         Emergency       Home w/ Home Health Services
# 2                    3         Emergency       Home w/ Home Health Services
# 3                    5          Elective       Home w/ Home Health Services
# 4                    4          Elective  Inpatient Rehabilitation Facility
# ...                ...               ...                                ...
# 2622128             29         Emergency       Home w/ Home Health Services
# 2622129              1            Urgent                  Home or Self Care
# 2622130              4         Emergency                  Home or Self Care
# 2622131              1         Emergency                  Home or Self Care
# 2622132              1         Emergency                  Home or Self Care
#
#          Discharge Year  CCS Diagnosis Code CCS Diagnosis Description  \
# 0                  2010               135.0      INTESTINAL INFECTION
# 1                  2010               231.0            OTHER FRACTURE
# 2                  2010                42.0      SECONDARY MALIGNANCY
# 3                  2010               254.0   REHAB/PROSTH FIT/ADJUST
# 4                  2010               203.0            OSTEOARTHRITIS
# ...                 ...                 ...                       ...
# 2622128            2010               181.0      OTHR PREGNANCY COMPL
# 2622129            2010               181.0      OTHR PREGNANCY COMPL
# 2622130            2010               178.0          INDUCED ABORTION
# 2622131            2010               181.0      OTHR PREGNANCY COMPL
# 2622132            2010               177.0      SPONTANEOUS ABORTION
#
#          CCS Procedure Code CCS Procedure Description  APR DRG Code  \
# 0                       0.0                   NO PROC           249
# 1                      61.0   OT OR PRCS VES NOT HEAD           912
# 2                       0.0                   NO PROC           240
# 3                     215.0        OT PHYS THER/REHAB           860
# 4                     153.0   HIP REPLACEMENT,TOT/PRT           301
# ...                     ...                       ...           ...
# 2622128                75.0      SMALL BOWEL RESECTON           546
# 2622129               128.0   DX DILAT/CURETTAGE -D&C           544
# 2622130               126.0   ABORTION (TERM OF PREG)           544
# 2622131               127.0   D&C; ASPIR AFT DLV/ABOR           544
# 2622132               127.0   D&C; ASPIR AFT DLV/ABOR           544
#
#                                        APR DRG Description  APR MDC Code  \
# 0         NON-BACTERIAL GASTROENTERITIS, NAUSEA & VOMITING             6
# 1        MUSCULOSKELETAL & OTHER PROCEDURES FOR MULTIPL...            25
# 2                                     DIGESTIVE MALIGNANCY             6
# 3                                           REHABILITATION            23
# 4                                    HIP JOINT REPLACEMENT             8
# ...                                                    ...           ...
# 2622128  OTHER O.R. PROC FOR OBSTETRIC DIAGNOSES EXCEPT...            14
# 2622129  D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY FOR O...            14
# 2622130  D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY FOR O...            14
# 2622131  D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY FOR O...            14
# 2622132  D&C, ASPIRATION CURETTAGE OR HYSTEROTOMY FOR O...            14
#
#                                        APR MDC Description  \
# 0           Diseases and Disorders of the Digestive System
# 1                              Multiple Significant Trauma
# 2           Diseases and Disorders of the Digestive System
# 3        Rehabilitation, Aftercare, Other Factors Influ...
# 4        Diseases and Disorders of the Musculoskeletal ...
# ...                                                    ...
# 2622128           Pregnancy, Childbirth and the Puerperium
# 2622129           Pregnancy, Childbirth and the Puerperium
# 2622130           Pregnancy, Childbirth and the Puerperium
# 2622131           Pregnancy, Childbirth and the Puerperium
# 2622132           Pregnancy, Childbirth and the Puerperium
#
#          APR Severity of Illness Code APR Severity of Illness Description  \
# 0                                   1                               Minor
# 1                                   3                               Major
# 2                                   3                               Major
# 3                                   2                            Moderate
# 4                                   1                               Minor
# ...                               ...                                 ...
# 2622128                             3                               Major
# 2622129                             2                            Moderate
# 2622130                             1                               Minor
# 2622131                             1                               Minor
# 2622132                             2                            Moderate
#
#         APR Risk of Mortality APR Medical Surgical Description  \
# 0                       Minor                          Medical
# 1                     Extreme                         Surgical
# 2                       Major                          Medical
# 3                       Minor                          Medical
# 4                       Minor                         Surgical
# ...                       ...                              ...
# 2622128                 Minor                         Surgical
# 2622129                 Minor                         Surgical
# 2622130                 Minor                         Surgical
# 2622131                 Minor                         Surgical
# 2622132                 Minor                         Surgical
#
#         Source of Payment 1 Source of Payment 2 Source of Payment 3  \
# 0                Blue Cross            Self-Pay                 NaN
# 1         Insurance Company            Medicare          Blue Cross
# 2                  Medicare          Blue Cross            Self-Pay
# 3                  Medicare   Insurance Company            Self-Pay
# 4                  Medicare   Insurance Company            Self-Pay
# ...                     ...                 ...                 ...
# 2622128          Blue Cross            Self-Pay                 NaN
# 2622129          Blue Cross            Self-Pay                 NaN
# 2622130   Insurance Company            Self-Pay                 NaN
# 2622131            Self-Pay                 NaN                 NaN
# 2622132   Insurance Company                 NaN                 NaN
#
#          Attending Provider License Number  Operating Provider License Number  \
# 0                                   3623.0                                NaN
# 1                                 216951.0                           216951.0
# 2                                   3076.0                                NaN
# 3                                 140796.0                           140796.0
# 4                                 170254.0                           170254.0
# ...                                    ...                                ...
# 2622128                                NaN                                NaN
# 2622129                                NaN                                NaN
# 2622130                                NaN                                NaN
# 2622131                                NaN                                NaN
# 2622132                                NaN                                NaN
#
#          Other Provider License Number  Birth Weight Abortion Edit Indicator  \
# 0                                  NaN             0                       N
# 1                                  NaN             0                       N
# 2                                  NaN             0                       N
# 3                             170254.0             0                       N
# 4                             170254.0             0                       N
# ...                                ...           ...                     ...
# 2622128                            NaN             0                       Y
# 2622129                            NaN             0                       Y
# 2622130                            NaN             0                       Y
# 2622131                            NaN             0                       Y
# 2622132                            NaN             0                       Y
#
#         Emergency Department Indicator  Total Charges  Total Costs
# 0                                    Y        4476.23      1672.65
# 1                                    Y      148612.34     51414.70
# 2                                    N       16561.99      4032.49
# 3                                    N       13593.51      4947.81
# 4                                    N       31962.58     16988.33
# ...                                ...            ...          ...
# 2622128                              Y      230373.65     83223.46
# 2622129                              N       20335.27      7677.97
# 2622130                              Y       27775.54      9819.99
# 2622131                              Y       11738.58      3295.21
# 2622132                              Y       10513.56      3856.01
#
# [2622133 rows x 38 columns]

# %% [markdown]
# ## Exploratory Data Analysis (EDA) on Hospital Data
#
# In this section, we perform exploratory data analysis (EDA) on the hospital dataset `hospital_data`. We are using various operations and visualizations to gain insights into the data.

# %% [markdown]
# ### Checking for Missing Values
#
# We begin by checking for missing values in the dataset and calculating the percentage of missing values for each column.

# %%
hospital_data.isnull().sum()
# Out:
# index                                        0
# Health Service Area                       4887
# Hospital County                           4887
# Operating Certificate Number              4887
# Facility ID                               4887
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                       3201
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                        103
# Discharge Year                               0
# CCS Diagnosis Code                        2273
# CCS Diagnosis Description                 2273
# CCS Procedure Code                        2273
# CCS Procedure Description                 2273
# APR DRG Code                                 0
# APR DRG Description                          0
# APR MDC Code                                 0
# APR MDC Description                          0
# APR Severity of Illness Code                 0
# APR Severity of Illness Description        241
# APR Risk of Mortality                      241
# APR Medical Surgical Description             0
# Source of Payment 1                          0
# Source of Payment 2                     810381
# Source of Payment 3                    2040841
# Attending Provider License Number         4887
# Operating Provider License Number       670818
# Other Provider License Number          2133991
# Birth Weight                                 0
# Abortion Edit Indicator                      0
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %%
(hospital_data.isnull().sum())/hospital_data.shape[0]
# Out:
# index                                  0.000000
# Health Service Area                    0.001864
# Hospital County                        0.001864
# Operating Certificate Number           0.001864
# Facility ID                            0.001864
# Facility Name                          0.000000
# Age Group                              0.000000
# Zip Code - 3 digits                    0.001221
# Gender                                 0.000000
# Race                                   0.000000
# Ethnicity                              0.000000
# Length of Stay                         0.000000
# Type of Admission                      0.000000
# Patient Disposition                    0.000039
# Discharge Year                         0.000000
# CCS Diagnosis Code                     0.000867
# CCS Diagnosis Description              0.000867
# CCS Procedure Code                     0.000867
# CCS Procedure Description              0.000867
# APR DRG Code                           0.000000
# APR DRG Description                    0.000000
# APR MDC Code                           0.000000
# APR MDC Description                    0.000000
# APR Severity of Illness Code           0.000000
# APR Severity of Illness Description    0.000092
# APR Risk of Mortality                  0.000092
# APR Medical Surgical Description       0.000000
# Source of Payment 1                    0.000000
# Source of Payment 2                    0.309054
# Source of Payment 3                    0.778313
# Attending Provider License Number      0.001864
# Operating Provider License Number      0.255829
# Other Provider License Number          0.813838
# Birth Weight                           0.000000
# Abortion Edit Indicator                0.000000
# Emergency Department Indicator         0.000000
# Total Charges                          0.000000
# Total Costs                            0.000000
# dtype: float64

# %% [markdown]
# ### Analyzing Different types of features
# We explore the distribution of the different features by displaying the counts of its unique values.

# %%
hospital_data['APR Risk of Mortality'].value_counts()
# Out:
# APR Risk of Mortality
# Minor       1644151
# Moderate     554542
# Major        300829
# Extreme      122370
# Name: count, dtype: int64

# %%
hospital_data['Discharge Year'].value_counts()
# Out:
# Discharge Year
# 2010    2622133
# Name: count, dtype: int64

# %%
hospital_data['Abortion Edit Indicator'].value_counts()
# Out:
# Abortion Edit Indicator
# N    2617246
# Y       4887
# Name: count, dtype: int64

# %%
hospital_data_final['Age Group'].value_counts()
# Out:
# Age Group
# 70 or Older    724471
# 50 to 69       679466
# 30 to 49       544536
# 0 to 17        386842
# 18 to 29       279420
# Name: count, dtype: int64

# %%
hospital_data_final['Zip Code - 3 digits'].value_counts()
# Out:
# Zip Code - 3 digits
# 112      364357
# 104      243938
# 117      202733
# 100      201754
# 113      139877
#           ...
# 111.0         3
# 108.0         3
# 106.0         3
# 101.0         3
# 118.0         1
# Name: count, Length: 75, dtype: int64

# %%
hospital_data_final['Attending Provider License Number'].value_counts()
# Out:
# Attending Provider License Number
# 223563.0    4476
# 195267.0    4338
# 149709.0    3333
# 175020.0    3182
# 153130.0    2859
#             ...
# 188048.0       1
# 210130.0       1
# 240973.0       1
# 211688.0       1
# 199095.0       1
# Name: count, Length: 30086, dtype: int64

# %% [markdown]
# ### Data Preprocessing
# For further analysis, we create a new DataFrame hospital_data_final by dropping several columns that are not relevant to our analysis.

# %%
hospital_data_final = hospital_data.drop(['Abortion Edit Indicator','Discharge Year','Other Provider License Number', 'Operating Provider License Number', 'Source of Payment 3', 'Source of Payment 2', 'index','CCS Diagnosis Description','CCS Procedure Description', 'APR DRG Description', 'APR MDC Description', 'APR Severity of Illness Description'], axis=1)

# %%
hospital_data_final.head()
# Out:
#   Health Service Area Hospital County  Operating Certificate Number  \
# 0      Capital/Adiron          Albany                      101000.0
# 1      Capital/Adiron          Albany                      101000.0
# 2      Capital/Adiron          Albany                      101000.0
# 3      Capital/Adiron          Albany                      101000.0
# 4      Capital/Adiron          Albany                      101000.0
#
#    Facility ID                   Facility Name    Age Group  \
# 0          1.0  Albany Medical Center Hospital     18 to 29
# 1          1.0  Albany Medical Center Hospital     50 to 69
# 2          1.0  Albany Medical Center Hospital  70 or Older
# 3          1.0  Albany Medical Center Hospital  70 or Older
# 4          1.0  Albany Medical Center Hospital  70 or Older
#
#   Zip Code - 3 digits Gender   Race          Ethnicity Length of Stay  \
# 0                 NaN      F  White  Not Span/Hispanic              1
# 1                 NaN      M  White  Not Span/Hispanic             15
# 2                 NaN      M  White  Not Span/Hispanic              3
# 3                 NaN      F  White  Not Span/Hispanic              5
# 4                 NaN      F  White  Not Span/Hispanic              4
#
#   Type of Admission                Patient Disposition  CCS Diagnosis Code  \
# 0         Emergency                  Home or Self Care               135.0
# 1         Emergency       Home w/ Home Health Services               231.0
# 2         Emergency       Home w/ Home Health Services                42.0
# 3          Elective       Home w/ Home Health Services               254.0
# 4          Elective  Inpatient Rehabilitation Facility               203.0
#
#    CCS Procedure Code  APR DRG Code  APR MDC Code  \
# 0                 0.0           249             6
# 1                61.0           912            25
# 2                 0.0           240             6
# 3               215.0           860            23
# 4               153.0           301             8
#
#    APR Severity of Illness Code APR Risk of Mortality  \
# 0                             1                 Minor
# 1                             3               Extreme
# 2                             3                 Major
# 3                             2                 Minor
# 4                             1                 Minor
#
#   APR Medical Surgical Description Source of Payment 1  \
# 0                          Medical          Blue Cross
# 1                         Surgical   Insurance Company
# 2                          Medical            Medicare
# 3                          Medical            Medicare
# 4                         Surgical            Medicare
#
#    Attending Provider License Number  Birth Weight  \
# 0                             3623.0             0
# 1                           216951.0             0
# 2                             3076.0             0
# 3                           140796.0             0
# 4                           170254.0             0
#
#   Emergency Department Indicator  Total Charges  Total Costs
# 0                              Y        4476.23      1672.65
# 1                              Y      148612.34     51414.70
# 2                              N       16561.99      4032.49
# 3                              N       13593.51      4947.81
# 4                              N       31962.58     16988.33

# %% [markdown]
# ### Visualization: Histogram
# Finally, we create a histogram using Seaborn to visualize the distribution of different features in the hospital_data_final DataFrame.

# %%
sns.histplot(data = hospital_data_final, x='Health Service Area')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(30,7))
sns.histplot(data = hospital_data_final, x='Hospital County')
plt.xticks(rotation=60,fontsize=15)
plt.show()

# %%
sns.histplot(data = hospital_data_final, x='Operating Certificate Number', bins = 7)
plt.show()

# %%
plt.figure(figsize=(30,7))
sns.histplot(data = hospital_data_final, x='Patient Disposition')
plt.xticks(rotation=60,fontsize=15)
plt.show()

# %%
sns.histplot(data = hospital_data_final, x='CCS Diagnosis Code',bins=30)
plt.show()

# %%
sns.histplot(data = hospital_data_final, x='CCS Procedure Code',bins=10)
plt.show()

# %%
sns.histplot(data = hospital_data_final, x='APR Risk of Mortality')
plt.show()

# %% [markdown]
# ## Data Cleaning and Handling Missing Values
#
# In this section, we perform data cleaning and handle missing values in the `hospital_data` dataset.

# %% [markdown]
# ### Checking for Missing Values
#
# We start by checking the number of missing values for each column in the original `hospital_data` DataFrame.

# %%
hospital_data.isnull().sum()
# Out:
# index                                        0
# Health Service Area                       4887
# Hospital County                           4887
# Operating Certificate Number              4887
# Facility ID                               4887
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                       3201
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                        103
# Discharge Year                               0
# CCS Diagnosis Code                        2273
# CCS Diagnosis Description                 2273
# CCS Procedure Code                        2273
# CCS Procedure Description                 2273
# APR DRG Code                                 0
# APR DRG Description                          0
# APR MDC Code                                 0
# APR MDC Description                          0
# APR Severity of Illness Code                 0
# APR Severity of Illness Description        241
# APR Risk of Mortality                      241
# APR Medical Surgical Description             0
# Source of Payment 1                          0
# Source of Payment 2                     810381
# Source of Payment 3                    2040841
# Attending Provider License Number         4887
# Operating Provider License Number       670818
# Other Provider License Number          2133991
# Birth Weight                                 0
# Abortion Edit Indicator                      0
# Emergency Department Indicator               0
# Total Charges                                0
# Total Costs                                  0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values
# Next, we create a new DataFrame, hospital_data_final, by dropping rows with missing values in specific columns, including 'Health Service Area,' 'CCS Diagnosis Code,' and 'APR Risk of Mortality.' This step helps us ensure that the dataset contains only the rows with complete information in these critical columns.
#
#
# | Column Name                           | Missing Values |
# |--------------------------------------|----------------|
# | Health Service Area                   | 4,887          |
# | Hospital County                       | 4,887          |
# | Operating Certificate Number          | 4,887          |
# | Facility ID                           | 4,887          |
# | Attending Provider License Number     | 4,887          |
#
# | Column Name                           | Missing Values |
# |--------------------------------------|----------------|
# | CCS Diagnosis Code                    | 2,273          |
# | CCS Diagnosis Description             | 2,273          |
# | CCS Procedure Code                    | 2,273          |
# | CCS Procedure Description             | 2,273          |
#
# | Column Name                           | Missing Values |
#  |--------------------------------------|----------------|
#  | APR Severity of Illness Description  | 241            |
#  | APR Risk of Mortality Description    | 241            |
#
# All columns have null values in same rows as show . so I decided to drop them

# %%
hospital_data_final = hospital_data_final.dropna(subset=['Health Service Area', 'CCS Diagnosis Code', 'APR Risk of Mortality'])

# %% [markdown]
# ### Rechecking for Missing Values
# After handling missing values, we recheck the number of missing values in the hospital_data_final DataFrame to confirm that the specified columns no longer contain missing data.

# %%
hospital_data_final.isnull().sum()
# Out:
# Health Service Area                     0
# Hospital County                         0
# Operating Certificate Number            0
# Facility ID                             0
# Facility Name                           0
# Age Group                               0
# Zip Code - 3 digits                  3200
# Gender                                  0
# Race                                    0
# Ethnicity                               0
# Length of Stay                          0
# Type of Admission                       0
# Patient Disposition                   103
# CCS Diagnosis Code                      0
# CCS Procedure Code                      0
# APR DRG Code                            0
# APR MDC Code                            0
# APR Severity of Illness Code            0
# APR Risk of Mortality                   0
# APR Medical Surgical Description        0
# Source of Payment 1                     0
# Attending Provider License Number       0
# Birth Weight                            0
# Emergency Department Indicator          0
# Total Charges                           0
# Total Costs                             0
# dtype: int64

# %% [markdown]
# ### Handling Missing Values in 'Patient Disposition'
# We start by analyzing the distribution of values in the 'Patient Disposition' column and display the counts of each unique value.
# We fill missing values in the 'Patient Disposition' column with the value 'Home or Self Care' to provide a default disposition for records with missing information.

# %%
hospital_data_final['Patient Disposition'].value_counts()
# Out:
# Patient Disposition
# Home or Self Care                        1779863
# Home w/ Home Health Services              321491
# Skilled Nursing Home                      245913
# Left Against Medical Advice                56810
# Expired                                    56067
# Short-term Hospital                        47148
# Inpatient Rehabilitation Facility          44419
# Psychiatric Hospital or Unit of Hosp       15299
# Hospice - Medical Facility                  8619
# Another Type Not Listed                     8535
# Hospice - Home                              8530
# Facility w/ Custodial/Supportive Care       7280
# Cancer Center or Children's Hospital        5026
# Medicare Cert Long Term Care Hospital       3475
# Court/Law Enforcement                       3308
# Hosp Basd Medicare Approved Swing Bed       2041
# Federal Health Care Facility                 718
# Medicaid Cert Nursing Facility                46
# Critical Access Hospital                      44
# Name: count, dtype: int64

# %%
hospital_data_final['Patient Disposition'] = hospital_data_final['Patient Disposition'].fillna('Home or Self Care')

# %% [markdown]
# ### Data Transformation: 'Zip Code - 3 digits'
# Next, we perform transformations on the 'Zip Code - 3 digits' column. First, we replace any occurrences of 'OOS' with '000'. Then, we extract the first three digits from the remaining values.

# %%
hospital_data_final['Zip Code - 3 digits'] = hospital_data_final['Zip Code - 3 digits'].replace('OOS', '000')

# %%
hospital_data_final['Zip Code - 3 digits'] = hospital_data_final['Zip Code - 3 digits'].str[:3]

# %% [markdown]
# ### Analysis of 'Zip Code - 3 digits'
# We analyze the distribution of values in the 'Zip Code - 3 digits' column and display the counts of each unique value. Additionally, we create a histogram plot to visualize the distribution.

# %%
hospital_data_final['Zip Code - 3 digits'].value_counts()
# Out:
# Zip Code - 3 digits
# 112    363089
# 104    243067
# 117    202368
# 100    201460
# 113    139537
# 115    102190
# 114     99958
# 000     74129
# 142     72205
# 105     68472
# 103     67927
# 109     63410
# 146     58400
# 125     50496
# 140     49891
# 130     41087
# 120     36700
# 119     36674
# 107     35472
# 145     32411
# 121     31875
# 144     31428
# 110     30818
# 136     29869
# 132     29731
# 148     29171
# 128     27337
# 134     24615
# 141     23735
# 116     23470
# 111     22881
# 124     20976
# 147     20795
# 131     19465
# 123     19009
# 122     18986
# 133     17664
# 129     17292
# 138     14849
# 137     14793
# 127     13877
# 135     12150
# 126     12082
# 143     11301
# 108     10702
# 106     10169
# 139      9488
# 118      9268
# 149      8448
# 101      6348
# Name: count, dtype: int64

# %%
plt.figure(figsize=(30,7))
sns.histplot(data = hospital_data_final, x='Zip Code - 3 digits')
plt.xticks(fontsize=15, rotation=45)
plt.show()

# %% [markdown]
# ###  Handling Missing Values in 'Zip Code - 3 digits'
# Lastly, we fill missing values in the 'Zip Code - 3 digits' column with the mode of the corresponding 'Zip Code - 3 digits' values for each 'Hospital County.'

# %%
hospital_data_final['Zip Code - 3 digits'] = hospital_data_final['Zip Code - 3 digits'].fillna(hospital_data_final.groupby('Hospital County')['Zip Code - 3 digits'].transform(lambda x: x.mode().iloc[0]))

# %% [markdown]
# ### Rechecking for Missing Values
# After the transformations and handling of missing values, we recheck the number of missing values in the hospital_data_final DataFrame.

# %%
hospital_data_final.isnull().sum()
# Out:
# Health Service Area                  0
# Hospital County                      0
# Operating Certificate Number         0
# Facility ID                          0
# Facility Name                        0
# Age Group                            0
# Zip Code - 3 digits                  0
# Gender                               0
# Race                                 0
# Ethnicity                            0
# Length of Stay                       0
# Type of Admission                    0
# Patient Disposition                  0
# CCS Diagnosis Code                   0
# CCS Procedure Code                   0
# APR DRG Code                         0
# APR MDC Code                         0
# APR Severity of Illness Code         0
# APR Risk of Mortality                0
# APR Medical Surgical Description     0
# Source of Payment 1                  0
# Attending Provider License Number    0
# Birth Weight                         0
# Emergency Department Indicator       0
# Total Charges                        0
# Total Costs                          0
# dtype: int64

# %% [markdown]
# ## Data Transformation and Label Encoding
#
# In this section, we perform data transformation and label encoding on selected columns in the `hospital_data_final` DataFrame. We also handle the 'Length of Stay' column.

# %% [markdown]
# ### Label Encoding
#
# We use label encoding to transform categorical columns into numerical values for modeling. The following columns are encoded:
# - 'Zip Code - 3 digits'
# - 'Health Service Area'
# - 'Hospital County'
# - 'Facility Name'
# - 'Gender'
# - 'Race'
# - 'Ethnicity'
# - 'Type of Admission'
# - 'Patient Disposition'
# - 'APR Risk of Mortality'
# - 'APR Medical Surgical Description'
# - 'Source of Payment 1'
# - 'Emergency Department Indicator'
# - 'Age Group'

# %%
hospital_data_final
# Out:
#         Health Service Area Hospital County  Operating Certificate Number  \
# 0            Capital/Adiron          Albany                      101000.0
# 1            Capital/Adiron          Albany                      101000.0
# 2            Capital/Adiron          Albany                      101000.0
# 3            Capital/Adiron          Albany                      101000.0
# 4            Capital/Adiron          Albany                      101000.0
# ...                     ...             ...                           ...
# 2617241          Central NY        Onondaga                     3301008.0
# 2617242          Central NY        Onondaga                     3301008.0
# 2617243          Central NY        Onondaga                     3301008.0
# 2617244          Central NY        Onondaga                     3301008.0
# 2617245          Central NY        Onondaga                     3301008.0
#
#          Facility ID                            Facility Name    Age Group  \
# 0                1.0           Albany Medical Center Hospital     18 to 29
# 1                1.0           Albany Medical Center Hospital     50 to 69
# 2                1.0           Albany Medical Center Hospital  70 or Older
# 3                1.0           Albany Medical Center Hospital  70 or Older
# 4                1.0           Albany Medical Center Hospital  70 or Older
# ...              ...                                      ...          ...
# 2617241       9059.0  Crouse Hospital - Commonwealth Division     30 to 49
# 2617242       9059.0  Crouse Hospital - Commonwealth Division     18 to 29
# 2617243       9059.0  Crouse Hospital - Commonwealth Division     30 to 49
# 2617244       9059.0  Crouse Hospital - Commonwealth Division     30 to 49
# 2617245       9059.0  Crouse Hospital - Commonwealth Division     50 to 69
#
#         Zip Code - 3 digits Gender   Race          Ethnicity Length of Stay  \
# 0                       122      F  White  Not Span/Hispanic              1
# 1                       122      M  White  Not Span/Hispanic             15
# 2                       122      M  White  Not Span/Hispanic              3
# 3                       122      F  White  Not Span/Hispanic              5
# 4                       122      F  White  Not Span/Hispanic              4
# ...                     ...    ...    ...                ...            ...
# 2617241                 148      F  White  Not Span/Hispanic             30
# 2617242                 149      F  White  Not Span/Hispanic             31
# 2617243                 149      M  White  Not Span/Hispanic             36
# 2617244                 149      F  White  Not Span/Hispanic             31
# 2617245                 000      F  White  Not Span/Hispanic             44
#
#         Type of Admission                Patient Disposition  \
# 0               Emergency                  Home or Self Care
# 1               Emergency       Home w/ Home Health Services
# 2               Emergency       Home w/ Home Health Services
# 3                Elective       Home w/ Home Health Services
# 4                Elective  Inpatient Rehabilitation Facility
# ...                   ...                                ...
# 2617241          Elective                  Home or Self Care
# 2617242          Elective                  Home or Self Care
# 2617243          Elective                  Home or Self Care
# 2617244          Elective                  Home or Self Care
# 2617245          Elective                  Home or Self Care
#
#          CCS Diagnosis Code  CCS Procedure Code  APR DRG Code  APR MDC Code  \
# 0                     135.0                 0.0           249             6
# 1                     231.0                61.0           912            25
# 2                      42.0                 0.0           240             6
# 3                     254.0               215.0           860            23
# 4                     203.0               153.0           301             8
# ...                     ...                 ...           ...           ...
# 2617241               661.0               218.0           772            20
# 2617242               660.0               218.0           772            20
# 2617243               660.0               219.0           772            20
# 2617244               660.0               219.0           772            20
# 2617245               660.0               219.0           772            20
#
#          APR Severity of Illness Code APR Risk of Mortality  \
# 0                                   1                 Minor
# 1                                   3               Extreme
# 2                                   3                 Major
# 3                                   2                 Minor
# 4                                   1                 Minor
# ...                               ...                   ...
# 2617241                             2                 Minor
# 2617242                             2                 Minor
# 2617243                             2                 Minor
# 2617244                             2                 Minor
# 2617245                             2                 Minor
#
#         APR Medical Surgical Description Source of Payment 1  \
# 0                                Medical          Blue Cross
# 1                               Surgical   Insurance Company
# 2                                Medical            Medicare
# 3                                Medical            Medicare
# 4                               Surgical            Medicare
# ...                                  ...                 ...
# 2617241                          Medical            Medicaid
# 2617242                          Medical            Medicaid
# 2617243                          Medical            Medicaid
# 2617244                          Medical            Medicaid
# 2617245                          Medical            Self-Pay
#
#          Attending Provider License Number  Birth Weight  \
# 0                                   3623.0             0
# 1                                 216951.0             0
# 2                                   3076.0             0
# 3                                 140796.0             0
# 4                                 170254.0             0
# ...                                    ...           ...
# 2617241                           161633.0             0
# 2617242                           169629.0             0
# 2617243                           169629.0             0
# 2617244                           169629.0             0
# 2617245                           169629.0             0
#
#         Emergency Department Indicator  Total Charges  Total Costs
# 0                                    Y        4476.23      1672.65
# 1                                    Y      148612.34     51414.70
# 2                                    N       16561.99      4032.49
# 3                                    N       13593.51      4947.81
# 4                                    N       31962.58     16988.33
# ...                                ...            ...          ...
# 2617241                              N       24363.22     10878.72
# 2617242                              N       22463.33      9822.01
# 2617243                              N       25967.78     11466.50
# 2617244                              N       21571.25      9462.02
# 2617245                              Y       33865.98     14702.06
#
# [2614735 rows x 26 columns]

# %%
hospital_data_final[['Zip Code - 3 digits','Health Service Area','Hospital County','Facility Name','Gender','Race','Ethnicity','Type of Admission','Patient Disposition','APR Risk of Mortality','APR Medical Surgical Description','Source of Payment 1','Emergency Department Indicator','Age Group']] = hospital_data_final[['Zip Code - 3 digits','Health Service Area','Hospital County','Facility Name','Gender','Race','Ethnicity','Type of Admission','Patient Disposition','APR Risk of Mortality','APR Medical Surgical Description','Source of Payment 1','Emergency Department Indicator','Age Group']].apply(LabelEncoder().fit_transform)

# %% [markdown]
# ### Data Transformation: 'Length of Stay'
# To handle the 'Length of Stay' column, we first identify and replace a specific value 'a' with '120' (an example for illustration).

# %%
type(hospital_data_final['Length of Stay'][0])
# Out:
# str

# %%
a=hospital_data_final['Length of Stay'][14]
a
# Out:
# '120 +'

# %%
hospital_data_final['Length of Stay'] = hospital_data_final['Length of Stay'].str.replace(a, '120')

# %% [markdown]
# Then, we define a custom function custom_length_of_stay to convert the 'Length of Stay' values to integers. It removes the '+' symbol from values ending with '+' and converts the remaining values to integers.

# %%
def custom_length_of_stay(val):
    if val.endswith('+'):
        return int(val.rstrip('+'))
    return int(val)

hospital_data_final['Length of Stay'] = hospital_data_final['Length of Stay'].apply(custom_length_of_stay)

# %%
hospital_data_final['Length of Stay'].head(20)
# Out:
# 0       1
# 1      15
# 2       3
# 3       5
# 4       4
# 5       3
# 6       4
# 7       1
# 8       1
# 9       2
# 10      9
# 11      9
# 12      1
# 13      5
# 14    120
# 15     13
# 16     18
# 17      1
# 18      8
# 19      1
# Name: Length of Stay, dtype: int64

# %% [markdown]
# After these transformations, we convert the 'Length of Stay' column to numeric data type.

# %%
hospital_data_final['Length of Stay'] = pd.to_numeric(hospital_data_final['Length of Stay'])

# %% [markdown]
# ### Almost Final DataFrame
#
#
# These operations prepare the data for machine learning and analysis, transforming categorical data into numerical form and ensuring the 'Length of Stay' column is in a suitable format for further processing.

# %%
hospital_data_final
# Out:
#          Health Service Area  Hospital County  Operating Certificate Number  \
# 0                          0                0                      101000.0
# 1                          0                0                      101000.0
# 2                          0                0                      101000.0
# 3                          0                0                      101000.0
# 4                          0                0                      101000.0
# ...                      ...              ...                           ...
# 2617241                    1               31                     3301008.0
# 2617242                    1               31                     3301008.0
# 2617243                    1               31                     3301008.0
# 2617244                    1               31                     3301008.0
# 2617245                    1               31                     3301008.0
#
#          Facility ID  Facility Name  Age Group  Zip Code - 3 digits  Gender  \
# 0                1.0              2          1                   22       0
# 1                1.0              2          3                   22       1
# 2                1.0              2          4                   22       1
# 3                1.0              2          4                   22       0
# 4                1.0              2          4                   22       0
# ...              ...            ...        ...                  ...     ...
# 2617241       9059.0             42          2                   48       0
# 2617242       9059.0             42          1                   49       0
# 2617243       9059.0             42          2                   49       1
# 2617244       9059.0             42          2                   49       0
# 2617245       9059.0             42          3                    0       0
#
#          Race  Ethnicity  Length of Stay  Type of Admission  \
# 0           3          0               1                  1
# 1           3          0              15                  1
# 2           3          0               3                  1
# 3           3          0               5                  0
# 4           3          0               4                  0
# ...       ...        ...             ...                ...
# 2617241     3          0              30                  0
# 2617242     3          0              31                  0
# 2617243     3          0              36                  0
# 2617244     3          0              31                  0
# 2617245     3          0              44                  0
#
#          Patient Disposition  CCS Diagnosis Code  CCS Procedure Code  \
# 0                          7               135.0                 0.0
# 1                          8               231.0                61.0
# 2                          8                42.0                 0.0
# 3                          8               254.0               215.0
# 4                         12               203.0               153.0
# ...                      ...                 ...                 ...
# 2617241                    7               661.0               218.0
# 2617242                    7               660.0               218.0
# 2617243                    7               660.0               219.0
# 2617244                    7               660.0               219.0
# 2617245                    7               660.0               219.0
#
#          APR DRG Code  APR MDC Code  APR Severity of Illness Code  \
# 0                 249             6                             1
# 1                 912            25                             3
# 2                 240             6                             3
# 3                 860            23                             2
# 4                 301             8                             1
# ...               ...           ...                           ...
# 2617241           772            20                             2
# 2617242           772            20                             2
# 2617243           772            20                             2
# 2617244           772            20                             2
# 2617245           772            20                             2
#
#          APR Risk of Mortality  APR Medical Surgical Description  \
# 0                            2                                 0
# 1                            0                                 1
# 2                            1                                 0
# 3                            2                                 0
# 4                            2                                 1
# ...                        ...                               ...
# 2617241                      2                                 0
# 2617242                      2                                 0
# 2617243                      2                                 0
# 2617244                      2                                 0
# 2617245                      2                                 0
#
#          Source of Payment 1  Attending Provider License Number  Birth Weight  \
# 0                          0                             3623.0             0
# 1                          2                           216951.0             0
# 2                          4                             3076.0             0
# 3                          4                           140796.0             0
# 4                          4                           170254.0             0
# ...                      ...                                ...           ...
# 2617241                    3                           161633.0             0
# 2617242                    3                           169629.0             0
# 2617243                    3                           169629.0             0
# 2617244                    3                           169629.0             0
# 2617245                    7                           169629.0             0
#
#          Emergency Department Indicator  Total Charges  Total Costs
# 0                                     1        4476.23      1672.65
# 1                                     1      148612.34     51414.70
# 2                                     0       16561.99      4032.49
# 3                                     0       13593.51      4947.81
# 4                                     0       31962.58     16988.33
# ...                                 ...            ...          ...
# 2617241                               0       24363.22     10878.72
# 2617242                               0       22463.33      9822.01
# 2617243                               0       25967.78     11466.50
# 2617244                               0       21571.25      9462.02
# 2617245                               1       33865.98     14702.06
#
# [2614735 rows x 26 columns]

# %% [markdown]
# ## Correlation Analysis and Feature Selection
#
# In this section, we perform correlation analysis and feature selection on the `hospital_data_final` DataFrame.

# %% [markdown]
# ### Correlation Heatmap
#
# We start by creating a correlation heatmap to visualize the relationships between the numerical variables in the dataset. The heatmap displays correlations between columns, and values are annotated for clarity.

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(hospital_data_final.corr(),annot=True, cmap='coolwarm',fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Feature Selection
# Next, we perform feature selection by removing columns that are less relevant to the analysis. We drop the following columns from the hospital_data_final DataFrame:
#
# 'APR DRG Code'
# 'Operating Certificate Number'
# 'Total Charges'

# %%
hospital_data_final = hospital_data_final.drop(['APR DRG Code','Operating Certificate Number','Total Charges'], axis=1)

# %% [markdown]
# ### Feature Selection
# Next, we perform feature selection by removing columns that are less relevant to the analysis. We drop the following columns from the hospital_data_final DataFrame:
#
# 'APR DRG Code'
# 'Operating Certificate Number'
# 'Total Charges'

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(hospital_data_final.corr(),annot=True, cmap='coolwarm',fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Final DataFrame
# The hospital_data_final DataFrame now contains the transformed and processed data.
#
# This updated heatmap shows the correlations with the selected features, making it easier to understand the relationships in the reduced dataset.
#
# These operations help in identifying and removing less relevant features, simplifying the dataset for subsequent analysis.

# %%
hospital_data_final
# Out:
#          Health Service Area  Hospital County  Facility ID  Facility Name  \
# 0                          0                0          1.0              2
# 1                          0                0          1.0              2
# 2                          0                0          1.0              2
# 3                          0                0          1.0              2
# 4                          0                0          1.0              2
# ...                      ...              ...          ...            ...
# 2617241                    1               31       9059.0             42
# 2617242                    1               31       9059.0             42
# 2617243                    1               31       9059.0             42
# 2617244                    1               31       9059.0             42
# 2617245                    1               31       9059.0             42
#
#          Age Group  Zip Code - 3 digits  Gender  Race  Ethnicity  \
# 0                1                   22       0     3          0
# 1                3                   22       1     3          0
# 2                4                   22       1     3          0
# 3                4                   22       0     3          0
# 4                4                   22       0     3          0
# ...            ...                  ...     ...   ...        ...
# 2617241          2                   48       0     3          0
# 2617242          1                   49       0     3          0
# 2617243          2                   49       1     3          0
# 2617244          2                   49       0     3          0
# 2617245          3                    0       0     3          0
#
#          Length of Stay  Type of Admission  Patient Disposition  \
# 0                     1                  1                    7
# 1                    15                  1                    8
# 2                     3                  1                    8
# 3                     5                  0                    8
# 4                     4                  0                   12
# ...                 ...                ...                  ...
# 2617241              30                  0                    7
# 2617242              31                  0                    7
# 2617243              36                  0                    7
# 2617244              31                  0                    7
# 2617245              44                  0                    7
#
#          CCS Diagnosis Code  CCS Procedure Code  APR MDC Code  \
# 0                     135.0                 0.0             6
# 1                     231.0                61.0            25
# 2                      42.0                 0.0             6
# 3                     254.0               215.0            23
# 4                     203.0               153.0             8
# ...                     ...                 ...           ...
# 2617241               661.0               218.0            20
# 2617242               660.0               218.0            20
# 2617243               660.0               219.0            20
# 2617244               660.0               219.0            20
# 2617245               660.0               219.0            20
#
#          APR Severity of Illness Code  APR Risk of Mortality  \
# 0                                   1                      2
# 1                                   3                      0
# 2                                   3                      1
# 3                                   2                      2
# 4                                   1                      2
# ...                               ...                    ...
# 2617241                             2                      2
# 2617242                             2                      2
# 2617243                             2                      2
# 2617244                             2                      2
# 2617245                             2                      2
#
#          APR Medical Surgical Description  Source of Payment 1  \
# 0                                       0                    0
# 1                                       1                    2
# 2                                       0                    4
# 3                                       0                    4
# 4                                       1                    4
# ...                                   ...                  ...
# 2617241                                 0                    3
# 2617242                                 0                    3
# 2617243                                 0                    3
# 2617244                                 0                    3
# 2617245                                 0                    7
#
#          Attending Provider License Number  Birth Weight  \
# 0                                   3623.0             0
# 1                                 216951.0             0
# 2                                   3076.0             0
# 3                                 140796.0             0
# 4                                 170254.0             0
# ...                                    ...           ...
# 2617241                           161633.0             0
# 2617242                           169629.0             0
# 2617243                           169629.0             0
# 2617244                           169629.0             0
# 2617245                           169629.0             0
#
#          Emergency Department Indicator  Total Costs
# 0                                     1      1672.65
# 1                                     1     51414.70
# 2                                     0      4032.49
# 3                                     0      4947.81
# 4                                     0     16988.33
# ...                                 ...          ...
# 2617241                               0     10878.72
# 2617242                               0      9822.01
# 2617243                               0     11466.50
# 2617244                               0      9462.02
# 2617245                               1     14702.06
#
# [2614735 rows x 23 columns]

# %% [markdown]
# ## Data Preparation for Machine Learning
#
# In this section, we prepare the data for machine learning by splitting it into features (X) and the target variable (y). We also perform data scaling and set up batch processing for model training.

# %% [markdown]
# ### Splitting Data
#
# We split the dataset into features (`X`) and the target variable (`y`). The target variable, 'APR Risk of Mortality,' is separated from the features.

# %%
X = hospital_data_final.drop('APR Risk of Mortality', axis=1)
y = hospital_data_final['APR Risk of Mortality']

# %% [markdown]
# ### Train-Test Split
# We further split the data into training and testing sets. In this case, 80% of the data is used for training, and 20% is reserved for testing. The random state is set to ensure reproducibility.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Data Scaling
# To standardize the feature values, we use the Min-Max scaling method with MinMaxScaler. We transform the training and testing data separately.

# %%
sc = MinMaxScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %% [markdown]
# ### Batch Processing
# We define a batch size of 128,000 as the number of samples in each batch. We also calculate the number of batches needed for the training data based on the batch size and the total number of samples.
#
# These data preparation steps are essential for machine learning, including splitting data into training and testing sets and scaling features. Additionally, batch processing may be useful for model training and evaluation, particularly for large datasets.

# %%
batch_size = 128000

# %%
len(X_train)
# Out:
# 2091788

# %%
num_batches = len(X_train) // batch_size
num_batches
# Out:
# 16

# %% [markdown]
# ## Model Training and Evaluation
#
# In this section, we perform model training and evaluation using Logistic Regression and k-Nearest Neighbors (KNN) classifiers. We use batch processing and grid search for hyperparameter tuning.

# %% [markdown]
# ### Logistic Regression
#
# We start by defining a parameter grid for hyperparameter tuning with logistic regression. We consider various values for 'C' (regularization strength), 'penalty' (regularization type), 'solver,' 'multi_class,' and 'max_iter.'

# %%
param_logistic = {
    'C': [ 0.1, 1, 10],
    'penalty': ['l1', 'l2'] ,
    'solver': ['liblinear', 'saga']  ,
    'multi_class': ['ovr'],
    'max_iter': [800],
}

# %% [markdown]
# We create a LogisticRegression model and use GridSearchCV to find the best combination of hyperparameters based on accuracy. We iterate over the batches of data and train the model.
#
# We print the best hyperparameters, accuracy, confusion matrix, precision, and recall for the logistic regression model.

# %%
logistic_regression = GridSearchCV(LogisticRegression(), param_grid = param_logistic, cv=2, scoring='accuracy')

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    X_batch = X_train_scaled[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]

    logistic_regression.fit(X_batch, y_batch)


y_pred_logistic = logistic_regression.predict(X_test_scaled)
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
print(f'Best Params : {logistic_regression.best_params_}')
print(f'Accuracy : {accuracy_logistic}\n\n')

confusion_logistic = confusion_matrix(y_test, y_pred_logistic)
precision_logistic = precision_score(y_test, y_pred_logistic,average='macro')
recall_logistic = recall_score(y_test, y_pred_logistic,average='macro')

print(f'Confusion Matrix:\n{confusion_logistic}')
print(f'Precision: {precision_logistic:.2f}')
print(f'Recall: {recall_logistic:.2f}')
# Out:
# Best Params : {'C': 10, 'max_iter': 800, 'multi_class': 'ovr', 'penalty': 'l1', 'solver': 'saga'}
# Accuracy : 0.752952019994378
#
#
# Confusion Matrix:
# [[ 14483   5524    571   4040]
#  [  5398   5666   6132  42940]
#  [    94    328 312610  14330]
#  [   672   1433  47731  60995]]
# Precision: 0.62
# Recall: 0.55

# %% [markdown]
# ### k-Nearest Neighbors (KNN)
# We follow a similar process for KNN. We define a parameter grid with 'n_neighbors' and 'weights' as the hyperparameters.

# %%
param_knn = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
}

# %% [markdown]
# We create a KNeighborsClassifier model, perform grid search for hyperparameter tuning, iterate over data batches for training, and evaluate the model.
#
# We print the best hyperparameters, accuracy, confusion matrix, precision, and recall for the KNN model.

# %%
knn_classifier = GridSearchCV(KNeighborsClassifier(), param_grid=param_knn, cv=2, scoring='accuracy')

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    X_batch = X_train_scaled[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]

    knn_classifier.fit(X_batch, y_batch)

y_pred_knn = knn_classifier.predict(X_test_scaled)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print(f'Best Params : {knn_classifier.best_params_}')
print(f'Accuracy : {accuracy_knn}\n\n')

confusion_knn = confusion_matrix(y_test, y_pred_knn)
precision_knn = precision_score(y_test, y_pred_knn,average='macro')
recall_knn = recall_score(y_test, y_pred_knn,average='macro')

print(f'Confusion Matrix:\n{confusion_knn}')
print(f'Precision: {precision_knn:.2f}')
print(f'Recall: {recall_knn:.2f}')
# Out:
# Best Params : {'n_neighbors': 7, 'weights': 'distance'}
# Accuracy : 0.7492996422199573
#
#
# Confusion Matrix:
# [[ 12628   8292    743   2955]
#  [  4908  26955   5469  22804]
#  [    70   2783 299502  25007]
#  [   690  18674  38708  52759]]
# Precision: 0.64
# Recall: 0.59

# %% [markdown]
# ### Decision Tree Classifier
#
# We start by defining a parameter grid for hyperparameter tuning with the Decision Tree Classifier. We consider various values for 'criterion' (impurity criterion) and 'max_depth' (maximum depth of the tree).

# %%
param_tree = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [20,30],
}

# %% [markdown]
# We create a DecisionTreeClassifier model and use GridSearchCV to find the best combination of hyperparameters based on accuracy. We iterate over the batches of data and train the model.
#
# We print the best hyperparameters, accuracy, confusion matrix, precision, and recall for the Decision Tree Classifier.

# %%
tree_classifier = GridSearchCV(DecisionTreeClassifier(), param_grid=param_tree, cv=2, scoring='accuracy')

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    X_batch = X_train_scaled[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]

    tree_classifier.fit(X_batch, y_batch)
    
y_pred_tree = tree_classifier.predict(X_test_scaled)
accuracy_tree = accuracy_score(y_test, y_pred_tree)
print(f'Best Params : {tree_classifier.best_params_}')
print(f'Accuracy : {accuracy_tree}\n\n')

confusion_tree = confusion_matrix(y_test, y_pred_tree)
precision_tree = precision_score(y_test, y_pred_tree,average='weighted')
recall_tree = recall_score(y_test, y_pred_tree,average='weighted')

print(f'Confusion Matrix:\n{confusion_tree}')
print(f'Precision: {precision_tree:.2f}')
print(f'Recall: {recall_tree:.2f}')
# Out:
# Best Params : {'criterion': 'gini', 'max_depth': 20}
# Accuracy : 0.7501850091883117
#
#
# Confusion Matrix:
# [[ 14811   7973    273   1561]
#  [  6384  29947   3941  19864]
#  [   261   4093 291724  31284]
#  [  1264  21221  32521  55825]]
# Precision: 0.75
# Recall: 0.75

# %% [markdown]
# ### Random Forest Classifier
# We follow a similar process for the Random Forest Classifier. We define a parameter grid with 'n_estimators' (number of trees in the forest), 'criterion,' and 'max_depth' as the hyperparameters.

# %%
param_forest = {
    'n_estimators': [50, 100, 200],
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 20, 30],
}

# %% [markdown]
# We create a RandomForestClassifier model, perform grid search for hyperparameter tuning, iterate over data batches for training, and evaluate the model.
#
# We print the best hyperparameters, accuracy, confusion matrix, precision, and recall for the Random Forest Classifier.

# %%
forest_classifier = GridSearchCV(RandomForestClassifier(), param_grid=param_forest, cv=2, scoring='accuracy')

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size

    X_batch = X_train_scaled[start_idx:end_idx]
    y_batch = y_train[start_idx:end_idx]

    forest_classifier.fit(X_batch, y_batch)

y_pred_forest = forest_classifier.predict(X_test_scaled)
accuracy_forest = accuracy_score(y_test, y_pred_forest)
print(f'Best Params  : {forest_classifier.best_params_}')
print(f'Accuracy : {accuracy_forest}\n\n')

confusion_forest = confusion_matrix(y_test, y_pred_forest)
precision_forest = precision_score(y_test, y_pred_forest,average='macro')
recall_forest = recall_score(y_test, y_pred_forest,average='macro')

print(f'Confusion Matrix:\n{confusion_forest}')
print(f'Precision: {precision_forest:.2f}')
print(f'Recall: {recall_forest:.2f}')
# Out:
# Best Params  : {'criterion': 'gini', 'max_depth': 10, 'n_estimators': 200}
# Accuracy : 0.7966065394772319
#
#
# Confusion Matrix:
# [[ 16802   6656    206    954]
#  [  4839  33115   2356  19826]
#  [    24    959 306025  20354]
#  [   248  16933  33009  60641]]
# Precision: 0.71
# Recall: 0.68

# %% [markdown]
# These operations provide an overview of model training, hyperparameter tuning, and evaluation for Logistic Regression , KNN classifiers ,the Decision Tree Classifier and Random Forest Classifier.

# %% [markdown]
# ## Model Evaluation and Comparison
#
# In this section, we evaluate and compare the performance of different machine learning models, including Logistic Regression, K-Nearest Neighbors (KNN), Decision Tree, and Random Forest. We calculate and visualize accuracy, precision, recall, and confusion matrices for these models.

# %% [markdown]
# ### Model Metrics and Visualization: Accuracy, Precision, and Recall
# We collect the precision, recall, and accuracy scores for each model and create bar charts to visually compare the accuracy, precision, and recall scores of the different models.

# %%
models = ['logistic_regression', 'KNN', 'Decision Tree ','Random Forest']
precision_scores = [precision_logistic, precision_knn, precision_tree,precision_forest]
recall_scores = [recall_logistic, recall_knn, recall_tree,recall_forest]
Accuracy_scores = [accuracy_logistic, accuracy_knn, accuracy_tree, accuracy_forest]
confusion_scores = [confusion_logistic, confusion_knn, confusion_tree,confusion_forest]


plt.figure(figsize=(10, 6))
plt.bar(models, Accuracy_scores, color='r', alpha=0.6, label='Accuracy')
plt.xlabel('Models or Settings')
plt.ylabel('Accuracy')
plt.legend()


plt.figure(figsize=(10, 6))
plt.bar(models, precision_scores, color='b', alpha=0.6, label='Precision')
plt.xlabel('Models or Settings')
plt.ylabel('Precision Score')
plt.legend()


plt.figure(figsize=(10, 6))
plt.bar(models, recall_scores, color='g', alpha=0.6, label='Recall')
plt.xlabel('Models or Settings')
plt.ylabel('Recall Score')
plt.legend()

plt.show()

# %% [markdown]
# ### Visualization: Confusion Matrix Heatmaps
# We display confusion matrix heatmaps for each model to visualize the performance in more detail.
#
# These visualizations and metrics provide a comprehensive comparison of the model performances, helping to assess which model is the most suitable for your task.

# %%
plt.figure(figsize=(30, 10))


clf_names = ['Logistic Regression', 'K-Nearest Neighbors', 'Decision Tree', 'Random Forest']

for i, confusion in enumerate(confusion_scores):

    plt.subplot(1, 4, i + 1)
    sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title(f'Confusion Matrix Heatmap\n({clf_names[i]})')

plt.tight_layout()
plt.show()
